# %%
import tweepy
from pprint import pprint #for printing the Tweet in a format 
import jsonpickle #for creating a pickle file for storing the tweets
#for getting Stream of Data
from tweepy import Stream
from tweepy.streaming import StreamListener

# %%
#Consumer Key (API Key), Consumer Secret (API Secret)
auth = tweepy.OAuthHandler('5cfaZLaj9rN8XutE26rGLIloc','GBesiG8rnDM0DgwDboltdPnVWordK4jUDKMh2pBPwSRmN91Ukt')
# Access Token, Access Token Secret
auth.set_access_token('915900688625934336-VHvLuMn2pMAFk6vqgvK3VwEuNOkTu5q','Z6ELPe9rnhWkP8JJQGbRAT82HLq4Ot1yBHQ441NkYRHaP')

api = tweepy.API(auth)
if (not api):
    print("Authentication failed :(")
else:
    print("Authentication successfull!!! :D")
# Out:
# Authentication successfull!!! :D

# %%
query = '#IndiaStrikesBack'  # this is what we're searching for
en_lang = 'en' # this is used to specify the language of the tweets
popular_results = 'popular' # used to specifiy the order of tweet results. Accepted values: popular|recent|mixec
extended_mode = 'extended' # used to tell the API not to truncate the tweet

# %%
search_results = api.search(q=query, lang=en_lang, result_type=popular_results, tweet_mode=extended_mode)

# %%
#Print the result
print_till = 100
counter = 0
for tweet in search_results:
    if counter < print_till:
        pprint(tweet._json)
        print('--------------------------------------------------------')
        counter += 1
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 05:48:26 +0000 2019',
#  'display_text_range': [0, 118],
#  'entities': {'hashtags': [{'indices': [13, 28], 'text': 'IndianAirForce'},
#                            {'indices': [101, 118], 'text': 'IndiaStrikesBack'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 47027,
#  'favorited': False,
#  'full_text': 'Proud of our #IndianAirForce fighters for destroying terror '
#               'camps. अंदर घुस के मारो ! Quiet no more! #IndiaStrikesBack',
#  'geo': None,
#  'id': 1100271349954764803,
#  'id_str': '1100271349954764803',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 9579,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Wed Apr 15 05:23:19 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': '',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'facebook.com/akshaykumaroff…',
#                                          'expanded_url': 'http://www.facebook.com/akshaykumarofficial',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/nVpOquvNp0'}]}},
#           'favourites_count': 1246,
#           'follow_request_sent': False,
#           'followers_count': 29669714,
#           'following': False,
#           'friends_count': 25,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 31348594,
#           'id_str': '31348594',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 15061,
#           'location': '',
#           'name': 'Akshay Kumar',
#           'notifications': False,
#           'profile_background_color': '9AE4E8',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1085067824840822785/ychTUtB8_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1085067824840822785/ychTUtB8_normal.jpg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': '121212',
#           'profile_sidebar_fill_color': 'B3B3B3',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'akshaykumar',
#           'statuses_count': 39279,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/nVpOquvNp0',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 03:57:20 +0000 2019',
#  'display_text_range': [0, 274],
#  'entities': {'hashtags': [{'indices': [12, 28], 'text': 'surgicalstrike2'},
#                            {'indices': [30, 38], 'text': 'Balakot'},
#                            {'indices': [257, 274], 'text': 'IndiaStrikesBack'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 6040,
#  'favorited': False,
#  'full_text': 'This is not #surgicalstrike2.\n'
#               '#Balakot is in Khyber Pakhtunkhwa, just 60 km or so from '
#               'Abbottabad where Pakistan military nestles, where Osama bin '
#               'Laden was killed.\n'
#               'Indian Mirage 2000s have struck deep in the heart of Pakistan.\n'
#               'This is a full-blown attack. #IndiaStrikesBack',
#  'geo': None,
#  'id': 1100243389428174849,
#  'id_str': '1100243389428174849',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 2621,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Jul 12 07:04:15 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Journalist. Editor of https://t.co/iyb4k6jdkE, media '
#                          'venture in English and Hindi of Asianet News '
#                          'Network. Views personal, retweets not necessarily '
#                          'endorsements',
#           'entities': {'description': {'urls': [{'display_url': 'MyNation.com',
#                                                  'expanded_url': 'http://www.MyNation.com',
#                                                  'indices': [22, 45],
#                                                  'url': 'https://t.co/iyb4k6jdkE'}]},
#                        'url': {'urls': [{'display_url': 'twitter.com/abhijitmajumder',
#                                          'expanded_url': 'https://twitter.com/abhijitmajumder',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/Q7SzYnf4z9'}]}},
#           'favourites_count': 614,
#           'follow_request_sent': False,
#           'followers_count': 520135,
#           'following': False,
#           'friends_count': 517,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 56039856,
#           'id_str': '56039856',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1075,
#           'location': 'New Delhi, India',
#           'name': 'Abhijit Majumder',
#           'notifications': False,
#           'profile_background_color': 'B2DFDA',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/56039856/1527593301',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1097722791753863168/1esHpmKd_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1097722791753863168/1esHpmKd_normal.jpg',
#           'profile_link_color': '93A644',
#           'profile_sidebar_border_color': 'EEEEEE',
#           'profile_sidebar_fill_color': 'FFFFFF',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'abhijitmajumder',
#           'statuses_count': 48159,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/Q7SzYnf4z9',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 06:42:12 +0000 2019',
#  'display_text_range': [0, 94],
#  'entities': {'hashtags': [{'indices': [35, 52], 'text': 'IndiaStrikesBack'},
#                            {'indices': [86, 94], 'text': 'JaiHind'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 11866,
#  'favorited': False,
#  'full_text': 'Our country gives a fitting reply. #IndiaStrikesBack . Salute '
#               'to the Indian Air Force #JaiHind',
#  'geo': None,
#  'id': 1100284881664278528,
#  'id_str': '1100284881664278528',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 3396,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Sep 20 16:46:20 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Actor',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 0,
#           'follow_request_sent': False,
#           'followers_count': 2913585,
#           'following': False,
#           'friends_count': 1,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 75823831,
#           'id_str': '75823831',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 2504,
#           'location': 'Hyderabad',
#           'name': 'Jr NTR',
#           'notifications': False,
#           'profile_background_color': '131516',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/75823831/1538395714',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1046756621081239557/oaJIfBD5_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1046756621081239557/oaJIfBD5_normal.jpg',
#           'profile_link_color': '009999',
#           'profile_sidebar_border_color': 'EEEEEE',
#           'profile_sidebar_fill_color': 'EFEFEF',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'tarak9999',
#           'statuses_count': 363,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 06:14:16 +0000 2019',
#  'display_text_range': [0, 62],
#  'entities': {'hashtags': [{'indices': [14, 29], 'text': 'IndianAirForce'},
#                            {'indices': [45, 62], 'text': 'IndiaStrikesBack'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 12843,
#  'favorited': False,
#  'full_text': 'Salute to the #IndianAirForce 🙏🏻. \nJAI HIND. #IndiaStrikesBack',
#  'geo': None,
#  'id': 1100277850391961600,
#  'id_str': '1100277850391961600',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 2253,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sat Apr 24 02:11:20 +0000 2010',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'film director',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 84,
#           'follow_request_sent': False,
#           'followers_count': 4443680,
#           'following': False,
#           'friends_count': 17,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 136479128,
#           'id_str': '136479128',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 2685,
#           'location': 'Hyderabad, India',
#           'name': 'rajamouli ss',
#           'notifications': False,
#           'profile_background_color': 'C6E2EE',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/136479128/1511025483',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1059087924325691395/RMvYQnmA_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1059087924325691395/RMvYQnmA_normal.jpg',
#           'profile_link_color': '1F98C7',
#           'profile_sidebar_border_color': 'C6E2EE',
#           'profile_sidebar_fill_color': 'DAECF4',
#           'profile_text_color': '663B12',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'ssrajamouli',
#           'statuses_count': 4910,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 04:35:35 +0000 2019',
#  'display_text_range': [0, 74],
#  'entities': {'hashtags': [{'indices': [43, 60], 'text': 'IndiaStrikesBack'},
#                            {'indices': [61, 69], 'text': 'JaiHind'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 12427,
#  'favorited': False,
#  'full_text': 'Indian Air Force 🇮🇳👏 Bohot Hard Bohot Hard #IndiaStrikesBack '
#               '#JaiHind 🇮🇳🇮🇳',
#  'geo': None,
#  'id': 1100253015724969985,
#  'id_str': '1100253015724969985',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': {'attributes': {},
#            'bounding_box': {'coordinates': [[[77.373474, 12.919037],
#                                              [77.739371, 12.919037],
#                                              [77.739371, 13.231381],
#                                              [77.373474, 13.231381]]],
#                             'type': 'Polygon'},
#            'contained_within': [],
#            'country': 'India',
#            'country_code': 'IN',
#            'full_name': 'Bengaluru, India',
#            'id': '1b8680cd52a711cb',
#            'name': 'Bengaluru',
#            'place_type': 'city',
#            'url': 'https://api.twitter.com/1.1/geo/id/1b8680cd52a711cb.json'},
#  'retweet_count': 2148,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Dec 27 13:36:59 +0000 2011',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Indian Cricketer 🇮🇳 | RCB | For Business Enquiries '
#                          'E-mail : tossco9@gmail.com',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'm.facebook.com/yuzi.23',
#                                          'expanded_url': 'https://m.facebook.com/yuzi.23',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/OdDQH0sE9m'}]}},
#           'favourites_count': 345,
#           'follow_request_sent': False,
#           'followers_count': 519692,
#           'following': False,
#           'friends_count': 200,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 447977892,
#           'id_str': '447977892',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 186,
#           'location': '',
#           'name': 'Yuzvendra Chahal',
#           'notifications': False,
#           'profile_background_color': '709397',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/447977892/1466054925',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/963641972035653632/-yLPoDF8_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/963641972035653632/-yLPoDF8_normal.jpg',
#           'profile_link_color': 'FF3300',
#           'profile_sidebar_border_color': '86A4A6',
#           'profile_sidebar_fill_color': 'A0C5C7',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'yuzi_chahal',
#           'statuses_count': 3105,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/OdDQH0sE9m',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 03:43:40 +0000 2019',
#  'display_text_range': [0, 259],
#  'entities': {'hashtags': [{'indices': [0, 10], 'text': 'EXCLUSIVE'},
#                            {'indices': [168, 185], 'text': 'IndiaStrikesBack'}],
#               'media': [{'display_url': 'pic.twitter.com/t3hYqOaLif',
#                          'expanded_url': 'https://twitter.com/CNNnews18/status/1100239952804118529/video/1',
#                          'id': 1100239258563026944,
#                          'id_str': '1100239258563026944',
#                          'indices': [260, 283],
#                          'media_url': 'http://pbs.twimg.com/media/D0TWZXfXgAEfDXs.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/media/D0TWZXfXgAEfDXs.jpg',
#                          'sizes': {'large': {'h': 720,
#                                              'resize': 'fit',
#                                              'w': 1280},
#                                    'medium': {'h': 675,
#                                               'resize': 'fit',
#                                               'w': 1200},
#                                    'small': {'h': 383,
#                                              'resize': 'fit',
#                                              'w': 680},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/t3hYqOaLif'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 18839785,
#                                  'id_str': '18839785',
#                                  'indices': [77, 90],
#                                  'name': 'Narendra Modi',
#                                  'screen_name': 'narendramodi'},
#                                 {'id': 61805109,
#                                  'id_str': '61805109',
#                                  'indices': [195, 211],
#                                  'name': 'Manoj Gupta',
#                                  'screen_name': 'manojkumargupta'},
#                                 {'id': 2916470293,
#                                  'id_str': '2916470293',
#                                  'indices': [226, 238],
#                                  'name': 'Zakka Jacob',
#                                  'screen_name': 'Zakka_Jacob'},
#                                 {'id': 1527024211,
#                                  'id_str': '1527024211',
#                                  'indices': [243, 259],
#                                  'name': 'Shreya Dhoundial',
#                                  'screen_name': 'shreyadhoundial'}]},
#  'extended_entities': {'media': [{'additional_media_info': {'description': 'Powered '
#                                                                            'by '
#                                                                            'SnappyTV',
#                                                             'embeddable': True,
#                                                             'monetizable': False,
#                                                             'title': 'Video'},
#                                   'display_url': 'pic.twitter.com/t3hYqOaLif',
#                                   'expanded_url': 'https://twitter.com/CNNnews18/status/1100239952804118529/video/1',
#                                   'id': 1100239258563026944,
#                                   'id_str': '1100239258563026944',
#                                   'indices': [260, 283],
#                                   'media_url': 'http://pbs.twimg.com/media/D0TWZXfXgAEfDXs.jpg',
#                                   'media_url_https': 'https://pbs.twimg.com/media/D0TWZXfXgAEfDXs.jpg',
#                                   'sizes': {'large': {'h': 720,
#                                                       'resize': 'fit',
#                                                       'w': 1280},
#                                             'medium': {'h': 675,
#                                                        'resize': 'fit',
#                                                        'w': 1200},
#                                             'small': {'h': 383,
#                                                       'resize': 'fit',
#                                                       'w': 680},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'video',
#                                   'url': 'https://t.co/t3hYqOaLif',
#                                   'video_info': {'aspect_ratio': [16, 9],
#                                                  'duration_millis': 532667,
#                                                  'variants': [{'bitrate': 832000,
#                                                                'content_type': 'video/mp4',
#                                                                'url': 'https://video.twimg.com/amplify_video/1100239258563026944/vid/640x360/GHuQmukHYPLL33sl.mp4?tag=9'},
#                                                               {'bitrate': 288000,
#                                                                'content_type': 'video/mp4',
#                                                                'url': 'https://video.twimg.com/amplify_video/1100239258563026944/vid/320x180/_5Nli0QdBknrxiP-.mp4?tag=9'},
#                                                               {'bitrate': 2176000,
#                                                                'content_type': 'video/mp4',
#                                                                'url': 'https://video.twimg.com/amplify_video/1100239258563026944/vid/1280x720/oUVNjr9dkdneTtgq.mp4?tag=9'},
#                                                               {'content_type': 'application/x-mpegURL',
#                                                                'url': 'https://video.twimg.com/amplify_video/1100239258563026944/pl/TCCw3J6QYjH9U9TH.m3u8?tag=9'}]}}]},
#  'favorite_count': 1335,
#  'favorited': False,
#  'full_text': '#EXCLUSIVE – Decision to strike back in Pakistan was taken by '
#               'Prime Minister @narendramodi himself. The decision was taken '
#               'immediately after the Pulwama terror attack. #IndiaStrikesBack '
#               '| Input: @manojkumargupta. | Details by @Zakka_Jacob and '
#               '@shreyadhoundial https://t.co/t3hYqOaLif',
#  'geo': None,
#  'id': 1100239952804118529,
#  'id_str': '1100239952804118529',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 574,
#  'retweeted': False,
#  'source': '<a href="http://snappytv.com" rel="nofollow">SnappyTV.com</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Fri Jun 01 20:31:01 +0000 2007',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Lightning fast alerts, #BreakingNews from India and '
#                          'the world.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'News18.com',
#                                          'expanded_url': 'http://www.News18.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/GtGDMfG5M1'}]}},
#           'favourites_count': 166,
#           'follow_request_sent': False,
#           'followers_count': 4107211,
#           'following': False,
#           'friends_count': 512,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 6509832,
#           'id_str': '6509832',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 6226,
#           'location': 'India',
#           'name': 'News18',
#           'notifications': False,
#           'profile_background_color': '4A913C',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/6509832/1551164393',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/923813836724977664/2wlt99tw_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/923813836724977664/2wlt99tw_normal.jpg',
#           'profile_link_color': 'E81C4F',
#           'profile_sidebar_border_color': 'A8C7F7',
#           'profile_sidebar_fill_color': 'C0DFEC',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'CNNnews18',
#           'statuses_count': 659259,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/GtGDMfG5M1',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 06:54:07 +0000 2019',
#  'display_text_range': [0, 251],
#  'entities': {'hashtags': [{'indices': [218, 233], 'text': 'IndianAirForce'},
#                            {'indices': [234, 251], 'text': 'IndiaStrikesBack'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 4909,
#  'favorited': False,
#  'full_text': 'Great job by the IAF. And great choice of words by govt '
#               '"non-military preemptive action against terrorists (and not '
#               'against Pak)". Makes it difficult for Pak to escalate. Josh and '
#               'Hosh both on display. Very well done. #IndianAirForce '
#               '#IndiaStrikesBack',
#  'geo': None,
#  'id': 1100287880654598144,
#  'id_str': '1100287880654598144',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 839,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Jun 04 10:30:19 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'The CB family!',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'chetanbhagat.com',
#                                          'expanded_url': 'http://www.chetanbhagat.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/1jDxAq7ImI'}]}},
#           'favourites_count': 2772,
#           'follow_request_sent': False,
#           'followers_count': 12401079,
#           'following': False,
#           'friends_count': 165,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 44588485,
#           'id_str': '44588485',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 7803,
#           'location': 'Mumbai',
#           'name': 'Chetan Bhagat',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1029242665705992192/nQqnqCUG_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1029242665705992192/nQqnqCUG_normal.jpg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'chetan_bhagat',
#           'statuses_count': 14109,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/1jDxAq7ImI',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 05:53:08 +0000 2019',
#  'display_text_range': [0, 171],
#  'entities': {'hashtags': [{'indices': [136, 153], 'text': 'IndiaStrikesBack'},
#                            {'indices': [154, 171], 'text': 'SurgicalStrikes2'}],
#               'media': [{'display_url': 'pic.twitter.com/888FpUtRYT',
#                          'expanded_url': 'https://twitter.com/ShivAroor/status/1100272531729113088/photo/1',
#                          'id': 1100272515417600001,
#                          'id_str': '1100272515417600001',
#                          'indices': [172, 195],
#                          'media_url': 'http://pbs.twimg.com/media/D0T0BfWXcAEqybW.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/media/D0T0BfWXcAEqybW.jpg',
#                          'sizes': {'large': {'h': 269,
#                                              'resize': 'fit',
#                                              'w': 433},
#                                    'medium': {'h': 269,
#                                               'resize': 'fit',
#                                               'w': 433},
#                                    'small': {'h': 269,
#                                              'resize': 'fit',
#                                              'w': 433},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/888FpUtRYT'}],
#               'symbols': [],
#               'urls': [{'display_url': 'indiatoday.in/india/story/ai…',
#                         'expanded_url': 'https://www.indiatoday.in/india/story/air-strike-india-attacks-pakistan-blow-by-blow-account-planning-1465159-2019-02-26',
#                         'indices': [112, 135],
#                         'url': 'https://t.co/fKmNvZkZYP'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/888FpUtRYT',
#                                   'expanded_url': 'https://twitter.com/ShivAroor/status/1100272531729113088/photo/1',
#                                   'id': 1100272515417600001,
#                                   'id_str': '1100272515417600001',
#                                   'indices': [172, 195],
#                                   'media_url': 'http://pbs.twimg.com/media/D0T0BfWXcAEqybW.jpg',
#                                   'media_url_https': 'https://pbs.twimg.com/media/D0T0BfWXcAEqybW.jpg',
#                                   'sizes': {'large': {'h': 269,
#                                                       'resize': 'fit',
#                                                       'w': 433},
#                                             'medium': {'h': 269,
#                                                        'resize': 'fit',
#                                                        'w': 433},
#                                             'small': {'h': 269,
#                                                       'resize': 'fit',
#                                                       'w': 433},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/888FpUtRYT'}]},
#  'favorite_count': 733,
#  'favorited': False,
#  'full_text': 'Clearance for today’s air strikes came 11 days ago on Feb 15 '
#               'when the IAF chief recommended an aerial response. '
#               'https://t.co/fKmNvZkZYP #IndiaStrikesBack #SurgicalStrikes2 '
#               'https://t.co/888FpUtRYT',
#  'geo': None,
#  'id': 1100272531729113088,
#  'id_str': '1100272531729113088',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 276,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sat May 01 21:01:07 +0000 2010',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Journalist at @Livefist & @IndiaToday | Author, '
#                          'Operation Jinnah & #IndiasMostFearless: '
#                          'https://t.co/RVfBYJr9KS | Tweets/RTs personal | '
#                          'shivaroor@gmail.com',
#           'entities': {'description': {'urls': [{'display_url': 'amzn.to/2x6UjJJ',
#                                                  'expanded_url': 'http://amzn.to/2x6UjJJ',
#                                                  'indices': [88, 111],
#                                                  'url': 'https://t.co/RVfBYJr9KS'}]},
#                        'url': {'urls': [{'display_url': 'facebook.com/aroorshiv',
#                                          'expanded_url': 'http://facebook.com/aroorshiv',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/1GhPcixZek'}]}},
#           'favourites_count': 908,
#           'follow_request_sent': False,
#           'followers_count': 845418,
#           'following': False,
#           'friends_count': 389,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 139189823,
#           'id_str': '139189823',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1087,
#           'location': 'Delhi',
#           'name': 'Shiv Aroor',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/139189823/1545916983',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1100130552781422593/Ip56t_rj_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1100130552781422593/Ip56t_rj_normal.jpg',
#           'profile_link_color': '005C99',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'EFEFEF',
#           'profile_text_color': '333333',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'ShivAroor',
#           'statuses_count': 71011,
#           'time_zone': None,
#           'translator_type': 'regular',
#           'url': 'https://t.co/1GhPcixZek',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 03:49:35 +0000 2019',
#  'display_text_range': [0, 221],
#  'entities': {'hashtags': [{'indices': [97, 105], 'text': 'Balakot'},
#                            {'indices': [149, 164], 'text': 'IndianAirForce'},
#                            {'indices': [204, 221], 'text': 'IndiaStrikesBack'}],
#               'media': [{'display_url': 'pic.twitter.com/wTep0JeG3H',
#                          'expanded_url': 'https://twitter.com/gauravbh/status/1100241441337499648/photo/1',
#                          'id': 1100241411117629442,
#                          'id_str': '1100241411117629442',
#                          'indices': [222, 245],
#                          'media_url': 'http://pbs.twimg.com/media/D0TXu-zXQAIlyU0.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/media/D0TXu-zXQAIlyU0.jpg',
#                          'sizes': {'large': {'h': 960,
#                                              'resize': 'fit',
#                                              'w': 1280},
#                                    'medium': {'h': 900,
#                                               'resize': 'fit',
#                                               'w': 1200},
#                                    'small': {'h': 510,
#                                              'resize': 'fit',
#                                              'w': 680},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/wTep0JeG3H'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/wTep0JeG3H',
#                                   'expanded_url': 'https://twitter.com/gauravbh/status/1100241441337499648/photo/1',
#                                   'id': 1100241411117629442,
#                                   'id_str': '1100241411117629442',
#                                   'indices': [222, 245],
#                                   'media_url': 'http://pbs.twimg.com/media/D0TXu-zXQAIlyU0.jpg',
#                                   'media_url_https': 'https://pbs.twimg.com/media/D0TXu-zXQAIlyU0.jpg',
#                                   'sizes': {'large': {'h': 960,
#                                                       'resize': 'fit',
#                                                       'w': 1280},
#                                             'medium': {'h': 900,
#                                                        'resize': 'fit',
#                                                        'w': 1200},
#                                             'small': {'h': 510,
#                                                       'resize': 'fit',
#                                                       'w': 680},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/wTep0JeG3H'},
#                                  {'display_url': 'pic.twitter.com/wTep0JeG3H',
#                                   'expanded_url': 'https://twitter.com/gauravbh/status/1100241441337499648/photo/1',
#                                   'id': 1100241422706446339,
#                                   'id_str': '1100241422706446339',
#                                   'indices': [222, 245],
#                                   'media_url': 'http://pbs.twimg.com/media/D0TXvp-WkAMP8oo.jpg',
#                                   'media_url_https': 'https://pbs.twimg.com/media/D0TXvp-WkAMP8oo.jpg',
#                                   'sizes': {'large': {'h': 581,
#                                                       'resize': 'fit',
#                                                       'w': 1032},
#                                             'medium': {'h': 581,
#                                                        'resize': 'fit',
#                                                        'w': 1032},
#                                             'small': {'h': 383,
#                                                       'resize': 'fit',
#                                                       'w': 680},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/wTep0JeG3H'},
#                                  {'display_url': 'pic.twitter.com/wTep0JeG3H',
#                                   'expanded_url': 'https://twitter.com/gauravbh/status/1100241441337499648/photo/1',
#                                   'id': 1100241433762717697,
#                                   'id_str': '1100241433762717697',
#                                   'indices': [222, 245],
#                                   'media_url': 'http://pbs.twimg.com/media/D0TXwTKX4AEgMQM.jpg',
#                                   'media_url_https': 'https://pbs.twimg.com/media/D0TXwTKX4AEgMQM.jpg',
#                                   'sizes': {'large': {'h': 581,
#                                                       'resize': 'fit',
#                                                       'w': 1032},
#                                             'medium': {'h': 581,
#                                                        'resize': 'fit',
#                                                        'w': 1032},
#                                             'small': {'h': 383,
#                                                       'resize': 'fit',
#                                                       'w': 680},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/wTep0JeG3H'}]},
#  'favorite_count': 2303,
#  'favorited': False,
#  'full_text': 'According to news reports around 200-300 casualties on Pakistan '
#               'side by Indian Air force \n'
#               '\n'
#               "JeM's #Balakot camp has been totally destroyed. Well done "
#               '#IndianAirForce \n'
#               '\n'
#               'How’s The Josh \n'
#               '\n'
#               'High Sir ✌️🇮🇳\n'
#               '\n'
#               ' ✈️\n'
#               '\n'
#               '#IndiaStrikesBack https://t.co/wTep0JeG3H',
#  'geo': None,
#  'id': 1100241441337499648,
#  'id_str': '1100241441337499648',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 776,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Wed Jul 22 12:29:43 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Advocate on Record - Supreme Court of India | BJP '
#                          'National Spokesperson | Former Hony. Secretary SCBA '
#                          '& Addi Advocate General UP | B.S. Finance USA',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'bjp.org',
#                                          'expanded_url': 'http://www.bjp.org',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/cjXqo5byqb'}]}},
#           'favourites_count': 18050,
#           'follow_request_sent': False,
#           'followers_count': 92590,
#           'following': False,
#           'friends_count': 935,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 59112159,
#           'id_str': '59112159',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 110,
#           'location': 'New Delhi, India',
#           'name': 'Gaurav Bhatia 🇮🇳',
#           'notifications': False,
#           'profile_background_color': '022330',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/59112159/1546335211',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1084054132779114496/A_Bn-pRN_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1084054132779114496/A_Bn-pRN_normal.jpg',
#           'profile_link_color': 'B38600',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'C0DFEC',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'gauravbh',
#           'statuses_count': 10514,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/cjXqo5byqb',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 04:35:48 +0000 2019',
#  'display_text_range': [0, 184],
# ...
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'ShivAroor',
#           'statuses_count': 71011,
#           'time_zone': None,
#           'translator_type': 'regular',
#           'url': 'https://t.co/1GhPcixZek',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 03:25:33 +0000 2019',
#  'display_text_range': [0, 184],
#  'entities': {'hashtags': [{'indices': [151, 168], 'text': 'IndiaStrikesBack'},
#                            {'indices': [169, 184], 'text': 'BreakingonNDTV'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 1961,
#  'favorited': False,
#  'full_text': 'Its official: Indian jets cross the LOC, strike at Jaish terror '
#               'camps. Mission Accomplished for now, India strikes back for the '
#               'men killed at Pulwama. #IndiaStrikesBack #BreakingonNDTV',
#  'geo': None,
#  'id': 1100235390508769280,
#  'id_str': '1100235390508769280',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 377,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sat Apr 18 09:44:12 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'You Dont Have to Shout to be Heard. Editorial '
#                          'Director, NDTV.Anchor, The NDTV Dialogues, #TheNews '
#                          'at 8pm',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 32,
#           'follow_request_sent': False,
#           'followers_count': 811526,
#           'following': False,
#           'friends_count': 236,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 32843303,
#           'id_str': '32843303',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1008,
#           'location': 'New Delhi,India ',
#           'name': 'sonia singh',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/32843303/1518415612',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/799278160797843456/54BftaVr_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799278160797843456/54BftaVr_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'soniandtv',
#           'statuses_count': 16613,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 03:33:35 +0000 2019',
#  'display_text_range': [0, 170],
#  'entities': {'hashtags': [{'indices': [19, 35], 'text': 'surgicalstrike2'},
#                            {'indices': [39, 47], 'text': 'Balakot'},
#                            {'indices': [52, 65], 'text': 'Muzaffaranad'},
#                            {'indices': [153, 170], 'text': 'IndiaStrikesBack'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 2138,
#  'favorited': False,
#  'full_text': 'Something tells me #surgicalstrike2 at #Balakot and '
#               '#Muzaffaranad is just a trailer. Pakistan is in for a lot more '
#               'trouble, soon from its western front. #IndiaStrikesBack',
#  'geo': None,
#  'id': 1100237412255584256,
#  'id_str': '1100237412255584256',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 673,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Jul 12 07:04:15 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Journalist. Editor of https://t.co/iyb4k6jdkE, media '
#                          'venture in English and Hindi of Asianet News '
#                          'Network. Views personal, retweets not necessarily '
#                          'endorsements',
#           'entities': {'description': {'urls': [{'display_url': 'MyNation.com',
#                                                  'expanded_url': 'http://www.MyNation.com',
#                                                  'indices': [22, 45],
#                                                  'url': 'https://t.co/iyb4k6jdkE'}]},
#                        'url': {'urls': [{'display_url': 'twitter.com/abhijitmajumder',
#                                          'expanded_url': 'https://twitter.com/abhijitmajumder',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/Q7SzYnf4z9'}]}},
#           'favourites_count': 614,
#           'follow_request_sent': False,
#           'followers_count': 520135,
#           'following': False,
#           'friends_count': 517,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 56039856,
#           'id_str': '56039856',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1075,
#           'location': 'New Delhi, India',
#           'name': 'Abhijit Majumder',
#           'notifications': False,
#           'profile_background_color': 'B2DFDA',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/56039856/1527593301',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1097722791753863168/1esHpmKd_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1097722791753863168/1esHpmKd_normal.jpg',
#           'profile_link_color': '93A644',
#           'profile_sidebar_border_color': 'EEEEEE',
#           'profile_sidebar_fill_color': 'FFFFFF',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'abhijitmajumder',
#           'statuses_count': 48159,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/Q7SzYnf4z9',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 04:51:34 +0000 2019',
#  'display_text_range': [0, 283],
#  'entities': {'hashtags': [{'indices': [10, 18], 'text': 'Balakot'},
#                            {'indices': [249, 265], 'text': 'SurgicalStrike2'},
#                            {'indices': [266, 283], 'text': 'IndiaStrikesBack'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 3718,
#  'favorited': False,
#  'full_text': "Strike on #Balakot shows India's Maturity as a Nation.We could "
#               'hv hit back badly &amp; could hv destroyed Civil installations '
#               'as well bt India chose to hit Terror Outfits only. It shows '
#               "India's commitment tht Its a fight Against Terror,No one else.\n"
#               '#SurgicalStrike2 #IndiaStrikesBack',
#  'geo': None,
#  'id': 1100257038670585858,
#  'id_str': '1100257038670585858',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 1321,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sat Nov 07 14:50:11 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Senior Anchor/Deputy Editor, India News.Worked with '
#                          'Ndtv, News24, Live India, Janmat, Jain Tv. Google '
#                          'Certified Trainer in Fact Check.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'sushantsinha.news',
#                                          'expanded_url': 'http://www.sushantsinha.news',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/vzikYxtJfj'}]}},
#           'favourites_count': 3323,
#           'follow_request_sent': False,
#           'followers_count': 41356,
#           'following': False,
#           'friends_count': 434,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 88199384,
#           'id_str': '88199384',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 82,
#           'location': 'New Delhi',
#           'name': 'Sushant Sinha',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/88199384/1529512116',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1083084958535626752/M-pNejbz_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1083084958535626752/M-pNejbz_normal.jpg',
#           'profile_link_color': 'DD2E44',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'SushantBSinha',
#           'statuses_count': 8189,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/vzikYxtJfj',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 26 06:29:18 +0000 2019',
#  'display_text_range': [0, 233],
#  'entities': {'hashtags': [{'indices': [216, 233], 'text': 'IndiaStrikesBack'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 784705308832694272,
#                                  'id_str': '784705308832694272',
#                                  'indices': [15, 23],
#                                  'name': 'Indian Air Force',
#                                  'screen_name': 'IAF_MCC'}]},
#  'favorite_count': 2815,
#  'favorited': False,
#  'full_text': 'Many thanks to @IAF_MCC for hitting terror outfits in Balakot '
#               'of Mansehra, PAK. The area has been known to have the so- '
#               'called Jihadi Training Camps since era of Zia-ul-Haq. Its a '
#               'fight Against Terror, No one else! \n'
#               '#IndiaStrikesBack',
#  'geo': None,
#  'id': 1100281632769085442,
#  'id_str': '1100281632769085442',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': {'attributes': {},
#            'bounding_box': {'coordinates': [[[60.4784431, 29.3774719],
#                                              [74.879448, 29.3774719],
#                                              [74.879448, 38.4834175],
#                                              [60.4784431, 38.4834175]]],
#                             'type': 'Polygon'},
#            'contained_within': [],
#            'country': 'Afghanistan',
#            'country_code': 'AF',
#            'full_name': 'Afghanistan',
#            'id': '9ac7aa903ba29bd1',
#            'name': 'Afghanistan',
#            'place_type': 'country',
#            'url': 'https://api.twitter.com/1.1/geo/id/9ac7aa903ba29bd1.json'},
#  'retweet_count': 1277,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Fri Feb 22 14:01:38 +0000 2013',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Former Director of Public Affairs and Spokesperson '
#                          'to The National Security Council of Afghanistan.',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 2327,
#           'follow_request_sent': False,
#           'followers_count': 28469,
#           'following': False,
#           'friends_count': 422,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 1208595276,
#           'id_str': '1208595276',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 49,
#           'location': 'Kabul, Afghanistan',
#           'name': 'Tawab Ghorzang',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1208595276/1495666716',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1096135170330103808/wLVU3U9O_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1096135170330103808/wLVU3U9O_normal.jpg',
#           'profile_link_color': '3B94D9',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'TawabGhorzang1',
#           'statuses_count': 6715,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
